# %%
import os
import json
import random

# Folder containing the JSON files
folder_path = "/Users/nickgutin/Documents/GitHub/congress-project/general bill info"

# List to hold all JSON data
all_json_data = []

# Loop through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".json"):  # Check if the file is a JSON file
        file_path = os.path.join(folder_path, filename)  # Full path to the file
        with open(file_path, "r") as file:
            try:
                data = json.load(file)  # Load the JSON file content
                sample = random.sample(data, min(len(data), 15))
                all_json_data.append(sample)  # Add the content to the list
            except json.JSONDecodeError:
                print(f"Error decoding {filename}")

all_json_data[6]
# Out:
# [{'congress': 116,
#   'latestAction': {'actionDate': '2020-01-08',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3161',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'National Biomedical Research Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3161?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2019-11-13',
#    'text': 'Referred to the House Committee on Oversight and Reform.'},
#   'number': '5070',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'A Just Society: The Mercy In Re-entry Act',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/116/hr/5070?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2019-03-13',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '766',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'PROTECT Asbestos Victims Act of 2019',
#   'type': 'S',
#   'updateDate': '2022-11-01',
#   'updateDateIncludingText': '2022-11-01',
#   'url': 'https://api.congress.gov/v3/bill/116/s/766?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2020-11-18',
#    'text': 'Received in the Senate and Read twice and referred to the Committee on the Judiciary.'},
#   'number': '4812',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Ensuring Compliance Against Drug Diversion Act of 2020',
#   'type': 'HR',
#   'updateDate': '2024-02-05',
#   'updateDateIncludingText': '2024-02-05',
#   'url': 'https://api.congress.gov/v3/bill/116/hr/4812?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2020-10-20',
#    'text': 'Became Public Law No: 116-173.'},
#   'number': '4779',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To extend the Undertaking Spam, Spyware, And Fraud Enforcement With Enforcers beyond Borders Act of 2006, and for other purposes.',
#   'type': 'HR',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/116/hr/4779?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2020-04-14',
#    'text': 'Referred to the House Committee on Education and Labor.'},
#   'number': '923',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Recognizing the contributions of distribution and warehousing workers during the 2020 coronavirus pandemic.',
#   'type': 'HRES',
#   'updateDate': '2024-02-06',
#   'updateDateIncludingText': '2024-02-06',
#   'url': 'https://api.congress.gov/v3/bill/116/hres/923?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2019-09-23',
#    'text': 'Referred to the Subcommittee on Economic Development, Public Buildings, and Emergency Management.'},
#   'number': '4434',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Appalachian Regional Commission Reauthorization Act',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/116/hr/4434?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2020-02-05',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 412.'},
#   'number': '450',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Veterans Improved Access and Care Act of 2020',
#   'type': 'S',
#   'updateDate': '2024-02-09',
#   'updateDateIncludingText': '2024-02-09',
#   'url': 'https://api.congress.gov/v3/bill/116/s/450?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2019-12-02',
#    'text': 'Resolution agreed to in Senate without amendment and with a preamble by Voice Vote. (consideration: CR S6791; text: 11/21/2019 CR S6761)'},
#   'number': '442',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution designating November 2019 as "National Runaway Prevention Month".',
#   'type': 'SRES',
#   'updateDate': '2022-10-28',
#   'updateDateIncludingText': '2022-10-28',
#   'url': 'https://api.congress.gov/v3/bill/116/sres/442?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2019-03-14',
#    'text': 'Referred to the House Committee on Ways and Means.'},
#   'number': '1770',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Student Agriculture Protection Act of 2019',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/116/hr/1770?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2019-08-16',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 179.'},
#   'number': '494',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'American Fisheries Advisory Committee Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/116/s/494?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2020-03-12',
#    'text': 'Referred to the House Committee on Energy and Commerce.'},
#   'number': '6256',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Five-Stars for Safe Cars Act',
#   'type': 'HR',
#   'updateDate': '2024-02-05',
#   'updateDateIncludingText': '2024-02-05',
#   'url': 'https://api.congress.gov/v3/bill/116/hr/6256?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2020-01-21',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '3225',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Eliminating Leftover Expenses for Campaigns from Taxpayers (ELECT) Act of 2020',
#   'type': 'S',
#   'updateDate': '2022-02-09',
#   'updateDateIncludingText': '2022-02-09',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3225?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2020-12-21',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '5084',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to increase transparency and access to group health plan and health insurance issuer reporting, and for other purposes.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/116/s/5084?format=json'},
#  {'congress': 116,
#   'latestAction': {'actionDate': '2020-09-23',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '4663',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Coin Metal Modification Authorization and Cost Savings Act of 2020',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/116/s/4663?format=json'}]

# %%
import requests

my_key = os.getenv("congress_apiKey")
con = '116'
code = 'hres'
num = '923'

api_url = f'https://api.congress.gov/v3/bill/{con}/{code}/{num}/text?api_key={my_key}'
test = requests.get(api_url)
test.json()
# Out:
# {'pagination': {'count': 1},
#  'request': {'billNumber': '923',
#   'billType': 'hres',
#   'billUrl': 'https://api.congress.gov/v3/bill/116/hres/923?format=json',
#   'congress': '116',
#   'contentType': 'application/json',
#   'format': 'json'},
#  'textVersions': [{'date': '2020-04-14T04:00:00Z',
#    'formats': [{'type': 'Formatted Text',
#      'url': 'https://www.congress.gov/116/bills/hres923/BILLS-116hres923ih.htm'},
#     {'type': 'PDF',
#      'url': 'https://www.congress.gov/116/bills/hres923/BILLS-116hres923ih.pdf'},
#     {'type': 'Formatted XML',
#      'url': 'https://www.congress.gov/116/bills/hres923/BILLS-116hres923ih.xml'}],
#    'type': 'Introduced in House'}]}

# %%
import asyncio
import aiohttp
import os
import json
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import boto3

load_dotenv()


async def fetch_text(session, url):
    """Fetch bill text asynchronously."""
    try:
        async with session.get(url) as response:
            if response.status == 200:
                return await response.text()  # Fetch text content
            else:
                print(f"Failed to fetch text URL {url} with status {response.status}")
                return None
    except Exception as e:
        print(f"Error fetching text URL {url}: {e}")
        return None

def save_code(code):
    
    if code == 'hr' or code == 'hres':
        return 'h'
    
    else:
        return 's'
    
async def process_bill_texts(congress_data):
    """Process bill metadata and fetch their text versions asynchronously."""
    my_key = os.getenv("congress_apiKey")
    bill_texts = []
    failed_bills = []  # Log for failed bills

    async with aiohttp.ClientSession() as session:
        for bill in congress_data:
            con = str(bill['congress'])
            code = bill['type'].lower()
            num = bill['number']
            save = save_code(code)

            # API call to get text versions
            try:
                #response = await fetch_url(session, api_url)
                
                #Fetch the latest text URL
                text_url = f"https://www.congress.gov/{con}/bills/{code}{num}/BILLS-{con}{code}{num}i{save}.htm"
                text_response = await fetch_text(session, text_url)

                if text_response:
                    soup = BeautifulSoup(text_response, "lxml")
                    bill_texts.append({
                        "id": f"{code}{num}",
                        "congress": con,
                        "text": soup.text
                    })
                    print(f"Saved text for bill {code}{num}")
                else:
                    print(f"Failed to fetch bill text for {code}{num}")
                    failed_bills.append({"id": f"{code}{num}", "congress": con})
    
            except Exception as e:
                print(f"Error processing bill {code}{num}: {e}")
                failed_bills.append({"id": f"{code}{num}", "congress": con})

    return bill_texts, failed_bills


def load_congress_data_from_s3():
    """Load congress data from S3."""
    bucket_name = os.getenv("bucket_name")
    folder_path = os.getenv("folder_path")
    s3 = boto3.client("s3")

    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=folder_path)
    congress_data = []
    full_congress = []

    if "Contents" in response:
        for obj in response["Contents"]:
            key = obj["Key"]
            if key.endswith(".json"):
                print(f"Fetching file: {key}")
                json_obj = s3.get_object(Bucket=bucket_name, Key=key)
                data = json.loads(json_obj["Body"].read().decode("utf-8"))
                congress_data.extend(data)
                
            full_congress.append(congress_data)
    else:
        print(f"No JSON files found in the S3 folder: {folder_path}")

    return full_congress


async def main():
    # Load congress data from S3
    print("Loading congress data from S3...")
    congress_data = all_json_data[6]
    
    print(f"Loaded {len(congress_data)} bills from S3.")

    # Process all bill texts
    bill_texts, failed_bills, file_name = await process_bill_texts(congress_data)
    

    with open("processed_bills.json", "w") as file:
        json.dump(bill_texts, file, indent=2)

asyncio.run(main())
# Out:
# Loading congress data from S3...
# Loaded 15 bills from S3.
# Saved text for bill s3161
# Saved text for bill hr5070
# Saved text for bill s766
# Saved text for bill hr4812
# Saved text for bill hr4779
# Saved text for bill hres923
# Saved text for bill hr4434
# Saved text for bill s450
# Saved text for bill sres442
# Saved text for bill hr1770
# Saved text for bill s494
# Saved text for bill hr6256
# Saved text for bill s3225
# Saved text for bill s5084
# Saved text for bill s4663
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 113
#     110     with open("processed_bills.json", "w") as file:
#     111         json.dump(bill_texts, file, indent=2)
# --> 113 asyncio.run(main())
#
# File ~/anaconda3/lib/python3.11/site-packages/nest_asyncio.py:35, in _patch_asyncio.<locals>.run(main, debug)
#      33 task = asyncio.ensure_future(main)
#      34 try:
# ---> 35     return loop.run_until_complete(task)
#      36 finally:
#      37     if not task.done():
#
# File ~/anaconda3/lib/python3.11/site-packages/nest_asyncio.py:90, in _patch_loop.<locals>.run_until_complete(self, future)
#      87 if not f.done():
#      88     raise RuntimeError(
#      89         'Event loop stopped before Future completed.')
# ---> 90 return f.result()
#
# File ~/anaconda3/lib/python3.11/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~/anaconda3/lib/python3.11/asyncio/tasks.py:267, in Task.__step(***failed resolving arguments***)
#     263 try:
#     264     if exc is None:
#     265         # We use the `send` method directly, because coroutines
#     266         # don't have `__iter__` and `__next__` methods.
# --> 267         result = coro.send(None)
#     268     else:
#     269         result = coro.throw(exc)
#
# Cell In[46], line 107, in main()
#     104 print(f"Loaded {len(congress_data)} bills from S3.")
#     106 # Process all bill texts
# --> 107 bill_texts, failed_bills, file_name = await process_bill_texts(congress_data)
#     110 with open("processed_bills.json", "w") as file:
#     111     json.dump(bill_texts, file, indent=2)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
def load_congress_data_from_s3():
    """Load congress data from S3, with each entry as a full JSON file."""
    bucket_name = os.getenv("bucket_name")
    folder_path = os.getenv("folder_path")
    s3 = boto3.client("s3")

    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=folder_path)
    congress_data = []

    if "Contents" in response:
        for obj in response["Contents"]:
            key = obj["Key"]
            if key.endswith(".json"):
                print(f"Fetching file: {key}")
                json_obj = s3.get_object(Bucket=bucket_name, Key=key)
                data = json.loads(json_obj["Body"].read().decode("utf-8"))
                congress_data.append(data)
    else:
        print(f"No JSON files found in the S3 folder: {folder_path}")

    return congress_data

# %%
test = load_congress_data_from_s3()
len(test)
test[0]
# Out:
# Fetching file: baseinfo/c110_allBills.json
# Fetching file: baseinfo/c111_allBills.json
# Fetching file: baseinfo/c112_allBills.json
# Fetching file: baseinfo/c113_allBills.json
# Fetching file: baseinfo/c114_allBills.json
# Fetching file: baseinfo/c115_allBills.json
# Fetching file: baseinfo/c116_allBills.json
# Fetching file: baseinfo/c117_allBills.json
# [{'congress': 110,
#   'latestAction': {'actionDate': '2009-01-03',
#    'text': 'Referred to the House Committee on House Administration.'},
#   'number': '107',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A concurrent resolution expressing the sense of Congress regarding the rights of Members of Congress (or any employee of a Member of Congress authorized by that Member) to lead tours of the United States Capitol complex.',
#   'type': 'SCONRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/sconres/107?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2009-01-02',
#    'text': 'Referred to the Subcommittee on Emergency Communications, Preparedness, and Response.'},
#   'number': '7329',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To amend the Robert T. Stafford Disaster Relief and Emergency Assistance Act to authorize funding for emergency management performance grants to provide for domestic preparedness and collective response to major disasters,and for other purposes.',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7329?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-23',
#    'text': 'Became Public Law No: 110-458.'},
#   'number': '7327',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Worker, Retiree, and Employer Recovery Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7327?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-23',
#    'text': 'Became Public Law No: 110-457.'},
#   'number': '7311',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'William Wilberforce Trafficking Victims Protection Reauthorization Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7311?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-23',
#    'text': 'Became Public Law No: 110-456.'},
#   'number': '6184',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': "America's Beautiful National Parks Quarter Dollar Coin Act of 2008",
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/6184?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-23',
#    'text': 'Became Public Law No: 110-460.'},
#   'number': '3712',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to make a technical correction in the Paul Wellstone and Pete Domenici Mental Health Parity and Addiction Equity Act of 2008.',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3712?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-23',
#    'text': 'Became Public Law No: 110-459.'},
#   'number': '3663',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Short-term Analog Flash and Emergency Readiness Act',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3663?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-19',
#    'text': 'Became Public Law No: 110-454.'},
#   'number': '6859',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the facility of the United States Postal Service located at 1501 South Slappey Boulevard in Albany, Georgia, as the "Dr. Walter Carl Gordon, Jr. Post Office Building".',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/6859?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-19',
#    'text': 'Became Public Law No: 110-455.'},
#   'number': '46',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A joint resolution ensuring that the compensation and other emoluments attached to the office of Secretary of State are those which were in effect on January 1, 2007.',
#   'type': 'SJRES',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/110/sjres/46?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Resolution agreed to in Senate without amendment and with a preamble by Unanimous Consent. (text as passed Senate: CR S10958)'},
#   'number': '728',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution designating January 2009 as "National Mentoring Month".',
#   'type': 'SRES',
#   'updateDate': '2019-11-15',
#   'updateDateIncludingText': '2019-11-15',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/728?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Resolution agreed to in Senate without amendment and with a preamble by Unanimous Consent. (text as passed Senate: CR S10958)'},
#   'number': '710',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution designating the week of February 2 through February 6, 2009, as "National Teen Dating Violence Awareness and Prevention Week".',
#   'type': 'SRES',
#   'updateDate': '2019-11-15',
#   'updateDateIncludingText': '2019-11-15',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/710?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Resolution agreed to in Senate without amendment and with a preamble by Unanimous Consent. (text as passed Senate: CR S10957)'},
#   'number': '664',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution celebrating the centennial of Union Station in Washington, District of Columbia.',
#   'type': 'SRES',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/664?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#   'number': '3741',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to amend the Clean Air Act to prohibit regulation of certain emissions from agricultural production.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3741?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Motion by Senator Reid to reconsider the vote by which cloture on the motion to proceed to the measure (Record Vote No. 215] was not invoked entered in Senate. (consideration: CR S10931)'},
#   'number': '7005',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Alternative Minimum Tax Relief Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7005?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '3740',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Digital TV Transition Fairness Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3740?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '3739',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Derivatives and Hedge Fund Regulatory Improvement Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3739?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '3738',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Home Retention and Economic Stabilization Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3738?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '3736',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to amend chapter 417 of title 49, United States Code, to require air carriers and ticket brokers to notify consumers of taxes, fees, charges, and fuel surcharges in a timely manner, and for other purposes.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3736?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '3737',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Sell Fuel Efficient Cars Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3737?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'By Senator Leahy from Committee on the Judiciary filed written report. Report No. 110-528.'},
#   'number': '3501',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'OLC Reporting Act of 2008',
#   'type': 'S',
#   'updateDate': '2022-02-03',
#   'updateDateIncludingText': '2022-02-03',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3501?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Read twice and referred to the Committee on Finance. (text of measure as introduced: CR S10951)'},
#   'number': '3735',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to amend the Internal Revenue Code of 1986 to provide for the eligibility of computer technology and equipment development businesses for enterprise zone incentives.',
#   'type': 'S',
#   'updateDate': '2019-11-15',
#   'updateDateIncludingText': '2019-11-15',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3735?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Read twice and referred to the Committee on Indian Affairs.'},
#   'number': '3734',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Pyramid Lake Paiute Tribe Fish Springs Ranch Settlement Act',
#   'type': 'S',
#   'updateDate': '2024-02-20',
#   'updateDateIncludingText': '2024-02-20',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3734?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Received in the Senate.'},
#   'number': '7321',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Auto Industry Financing and Restructuring Act',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7321?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Referred to the Subcommittee on Highways and Transit.'},
#   'number': '7340',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To direct the Secretary of Transportation to waive non-Federal share requirements for certain transportation programs and activities through September 30, 2009.',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7340?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Referred to the Subcommittee on Aviation.'},
#   'number': '7337',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To require certain air carriers of foreign air transportation to disclose the nature and source of delays and cancellations experienced by air travelers.',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7337?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#   'number': '3733',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to require the Federal Energy Regulatory Commission to hold at least 1 public hearing before issuance of a permit affecting public or private land use in a locality.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3733?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-11',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs. (text of measure as introduced: CR S10948-10949)'},
#   'number': '3732',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Promoting Small House Nursing Homes Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3732?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Financial Services.'},
#   'number': '3731',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Special Inspector General for the Troubled Asset Relief Program Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-06',
#   'updateDateIncludingText': '2024-02-06',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3731?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Resolution agreed to in Senate without amendment and with a preamble by Unanimous Consent. (text as passed Senate: CR S10885)'},
#   'number': '196',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution commending Idaho on winning the bid to host the 2009 Special Olympics World Winter Games.',
#   'type': 'SRES',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/196?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'actionTime': '18:16:59',
#    'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'number': '1534',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Providing for consideration of the bill (H.R. 7321) to authorize financial assistance to eligible automobile manufacturers, and for other purposes.',
#   'type': 'HRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hres/1534?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Motion to proceed to consideration of measure withdrawn in Senate. (consideration: CR S10859)'},
#   'number': '3297',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': "Advancing America's Priorities Act",
#   'type': 'S',
#   'updateDate': '2017-12-15',
#   'updateDateIncludingText': '2017-12-15',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3297?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the Committee on Environment and Public Works. (text of measure as introduced: CR S10884)'},
#   'number': '729',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution expressing the opposition of the Senate to a proposed regulation by the Environmental Protection Agency, now under review in the Office of Management and Budget, that would undercut air quality protections established by Congress in the Clean Air Act Amendments of 1977 for national parks, national wilderness areas, national monuments, and national seashores.',
#   'type': 'SRES',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/729?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'actionTime': '17:31:30',
#    'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'number': '1532',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Condemning the November 26, 2008, terrorist attacks in Mumbai, India, and expressing sympathy to the innocent victims from India and around the world.',
#   'type': 'HRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hres/1532?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3730',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Retooling the Health Care Workforce for an Aging America Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3730?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'actionTime': '16:03:41',
#    'text': 'Pursuant to the provisions of H. Res. 1533, H. Res. 1526 is laid on the table.'},
#   'number': '1526',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Providing for consideration of motions to suspend the rules and waiving a requirement of clause 6(a) of the rule XIII with respect to consideration of certain resolutions reported from the Committee on Rules.',
#   'type': 'HRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hres/1526?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'actionTime': '16:03:11',
#    'text': 'Pursuant to the provisions of H. Res. 1533, H. Res. 1516 is laid on the table.'},
#   'number': '1516',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Providing for consideration of the bill (H.R. 7201) to amend the Internal Revenue Code of 1986 to provide incentives for energy production and conservation, and for other purposes and providing for consideration of the bill (H.R. 7202) to amend the Internal Revenue Code of 1986 to extend certain expiring provisions, to provide individual income tax relief, and for other purposes.',
#   'type': 'HRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hres/1516?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'actionTime': '16:01:40',
#    'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'number': '1533',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Waiving a requirement of clause 6(a) of Rule XIII with respect to consideration of certain resolutions reported from the Committee on Rules.',
#   'type': 'HRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hres/1533?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#   'number': '3729',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Livestock Emissions Tax Ban Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3729?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#   'number': '3728',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to direct the Secretary of Transportation to waive non-Federal share requirements for certain transportation programs and activities through September 30, 2009.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3728?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Placed on the Union Calendar, Calendar No. 595.'},
#   'number': '7324',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Energy and Water Development and Related Agencies Appropriations Act, 2009',
#   'type': 'HR',
#   'updateDate': '2024-02-05',
#   'updateDateIncludingText': '2024-02-05',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7324?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Placed on the Union Calendar, Calendar No. 594.'},
#   'number': '7323',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Making appropriations for financial services and general government for the fiscal year ending September 30, 2009, and for other purposes.',
#   'type': 'HR',
#   'updateDate': '2024-02-05',
#   'updateDateIncludingText': '2024-02-05',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7323?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Placed on the Union Calendar, Calendar No. 593.'},
#   'number': '7322',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Commerce, Justice, Science, and Related Agencies Appropriations Act, 2009',
#   'type': 'HR',
#   'updateDate': '2024-02-05',
#   'updateDateIncludingText': '2024-02-05',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7322?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#   'number': '3727',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to require the designation of the Federal building located at McKinley Avenue and Third Street, S.W., Canton, Ohio, as the "Ralph Regula Federal Building".',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3727?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Read twice and referred to the Committee on the Judiciary. (text of measure as introduced: CR S10882)'},
#   'number': '3726',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Crime-Free Rural States Reauthorization Act',
#   'type': 'S',
#   'updateDate': '2019-11-15',
#   'updateDateIncludingText': '2019-11-15',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3726?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#   'number': '3725',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Green Jobs and Infrastructure Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3725?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Ways and Means.'},
#   'number': '7339',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Taxpayer Holiday Act for 2009',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7339?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Ways and Means.'},
#   'number': '7338',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Taxpayer Relief Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7338?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Foreign Affairs.'},
#   'number': '1535',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Expressing disapproval of the Agreement Between the United States of America and the Republic of Iraq on the Withdrawal of United States Forces from Iraq and the Organization of Their Activities During Their Temporary Presence in Iraq, and for other purposes.',
#   'type': 'HRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hres/1535?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Financial Services.'},
#   'number': '7333',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Special Inspector General for the Troubled Asset Relief Program Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-06',
#   'updateDateIncludingText': '2024-02-06',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7333?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Energy and Commerce.'},
#   'number': '7330',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'College Football Playoff Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-05',
#   'updateDateIncludingText': '2024-02-05',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7330?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the Committee on Oversight and Government Reform, and in addition to the Committee on Ways and Means, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#   'number': '7335',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To amend title 31, United States Code, to allow certain local tax debt to be collected through the reduction of Federal tax refunds.',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7335?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on the Judiciary.'},
#   'number': '7328',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': "Homeowners' Protection Act of 2008",
#   'type': 'HR',
#   'updateDate': '2018-11-21',
#   'updateDateIncludingText': '2018-11-21',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7328?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Ways and Means.'},
#   'number': '7336',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To amend the Internal Revenue Code of 1986 to prevent the alternative minimum tax from effectively repealing the Federal tax exemption for interest on State and local private activity bonds.',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7336?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on the Judiciary.'},
#   'number': '7332',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To amend title 18, United States Code, to provide penalties for counterfeiting or selling Presidential inauguration tickets, and for other purposes.',
#   'type': 'HR',
#   'updateDate': '2021-04-20',
#   'updateDateIncludingText': '2021-04-20',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7332?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Financial Services.'},
#   'number': '7326',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Systematic Foreclosure Prevention and Mortgage Modification Act',
#   'type': 'HR',
#   'updateDate': '2024-02-06',
#   'updateDateIncludingText': '2024-02-06',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7326?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Rules.'},
#   'number': '443',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To establish the Joint Select Committee on Reorganization and Reform of Foreign Assistance Agencies and Programs.',
#   'type': 'HCONRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hconres/443?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Oversight and Government Reform.'},
#   'number': '7331',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': "Save America's Cities Act of 2008",
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7331?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Financial Services.'},
#   'number': '7334',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'TARP Accountability Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-06',
#   'updateDateIncludingText': '2024-02-06',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7334?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-10',
#    'text': 'Referred to the House Committee on Ways and Means.'},
#   'number': '7325',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Economic Recovery Through Responsible Homeownership Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7325?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the House Committee on the Judiciary.'},
#   'number': '3711',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to authorize a cost of living adjustment for the Federal judiciary.',
#   'type': 'S',
#   'updateDate': '2018-11-21',
#   'updateDateIncludingText': '2018-11-21',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3711?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the House Committee on Oversight and Government Reform.'},
#   'number': '3681',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to designate the facility of the United States Postal Service located at 5070 Vegas Valley Drive in Las Vegas, Nevada, as the "Joseph A. Ryan Post Office Building".',
#   'type': 'S',
#   'updateDate': '2024-02-23',
#   'updateDateIncludingText': '2024-02-23',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3681?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S10837-10838; text as passed Senate: CR S10837-10838; text of measure as introduced: CR S10835)'},
#   'number': '727',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution honoring the victims of the bombing of Pan Am flight 103 on the twentieth anniversary of the tragedy.',
#   'type': 'SRES',
#   'updateDate': '2017-12-14',
#   'updateDateIncludingText': '2017-12-14',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/727?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S10837; text as passed Senate: CR S10837; text of measure as introduced: CR S10835)'},
#   'number': '726',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution designating December 13, 2008, as "Wreaths Across America Day".',
#   'type': 'SRES',
#   'updateDate': '2017-12-14',
#   'updateDateIncludingText': '2017-12-14',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/726?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S10837; text as passed Senate: CR S10837; text of measure as introduced: CR S10834-10835)'},
#   'number': '725',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution acknowledging the accomplishments and goals of the Youth Impact Program.',
#   'type': 'SRES',
#   'updateDate': '2017-12-14',
#   'updateDateIncludingText': '2017-12-14',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/725?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S10836-10837; text as passed Senate: CR S10836-10837; text of measure as introduced: CR S10834)'},
#   'number': '724',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution expressing the sense of the Senate on the horrific terrorist attacks and siege in Mumbai, India, beginning on November 26, 2008, and concluding on November 29, 2008.',
#   'type': 'SRES',
#   'updateDate': '2017-12-14',
#   'updateDateIncludingText': '2017-12-14',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/724?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Resolution agreed to in Senate without amendment and with a preamble by Unanimous Consent. (text as passed Senate: CR S10836)'},
#   'number': '719',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution recognizing National American Indian and Alaska Native Heritage Month and celebrating the heritage and culture of American Indians and Alaska Natives and the contributions of American Indians and Alaska Natives to the United States.',
#   'type': 'SRES',
#   'updateDate': '2024-02-20',
#   'updateDateIncludingText': '2024-02-20',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/719?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Resolution agreed to in Senate without amendment and with a preamble by Unanimous Consent. (text as passed Senate: CR S10835-10836)'},
#   'number': '720',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution supporting the goals and ideals of Pancreatic Cancer Awareness Month.',
#   'type': 'SRES',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/720?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Resolution agreed to in Senate without amendment and with a preamble by Unanimous Consent. (text as passed Senate: CR S10835)'},
#   'number': '718',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution designating November 30, 2008, as "Drive Safer Sunday".',
#   'type': 'SRES',
#   'updateDate': '2019-11-15',
#   'updateDateIncludingText': '2019-11-15',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/718?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the Subcommittee on Health.'},
#   'number': '7310',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Protecting Patients and Health Care Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-05',
#   'updateDateIncludingText': '2024-02-05',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7310?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Placed on the Union Calendar, Calendar No. 592.'},
#   'number': '6871',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Expedited Funds Availability Dollar Limits Adjustment Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-06',
#   'updateDateIncludingText': '2024-02-06',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/6871?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Read the second time. Placed on Senate Legislative Calendar under General Orders. Calendar No. 1129.'},
#   'number': '7006',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Disaster Tax Relief Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7006?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': "Referred to the Committee on Veterans' Affairs, and in addition to the Committee on Ways and Means, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned."},
#   'number': '7318',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To direct the Secretary of Veterans Affairs to acquire a parcel of land adjacent to Beaufort National Cemetery, Beaufort, South Carolina.',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7318?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': "Referred to the House Committee on Veterans' Affairs."},
#   'number': '7317',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To direct the Secretary of Veterans Affairs to conduct a study on the acquisition of a parcel of land adjacent to Beaufort National Cemetery, Beaufort, South Carolina.',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7317?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the Committee on Foreign Affairs, and in addition to the Committee on Rules, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#   'number': '7316',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Limitation on Nuclear Cooperation with the United Arab Emirates Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7316?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the House Committee on the Judiciary.'},
#   'number': '7320',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'For the relief of Rebeca Rojas de Guzman.',
#   'type': 'HR',
#   'updateDate': '2018-11-21',
#   'updateDateIncludingText': '2018-11-21',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7320?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the House Committee on the Judiciary.'},
#   'number': '7312',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To prohibit the selling and counterfeiting of tickets for a Presidential inaugural ceremony.',
#   'type': 'HR',
#   'updateDate': '2018-11-21',
#   'updateDateIncludingText': '2018-11-21',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7312?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the House Committee on the Judiciary.'},
#   'number': '7319',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'For the relief of Simeon Simeonov, Stela Simeonova, Stoyan Simeonov, and Vania Simeonova.',
#   'type': 'HR',
#   'updateDate': '2018-11-21',
#   'updateDateIncludingText': '2018-11-21',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7319?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the House Committee on Ways and Means.'},
#   'number': '7308',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'State and Local Sales Tax Deduction Expansion Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7308?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the House Committee on Oversight and Government Reform.'},
#   'number': '7313',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': "To amend chapter 89 of title 5, United States Code, to allow the United States Postal Service to pay its share of contributions for annuitants' health benefits out of the Postal Service Retiree Health Benefits Fund.",
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7313?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the House Committee on Ways and Means.'},
#   'number': '7315',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Retiree Relief Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7315?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the Committee on Ways and Means, and in addition to the Committee on Financial Services, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned.'},
#   'number': '7309',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To amend the Internal Revenue Code of 1986 to suspend employment and income taxes for the first two months of 2009, and for other purposes.',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7309?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Referred to the House Committee on Ways and Means.'},
#   'number': '7314',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Workforce Fairness and Tax Relief Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7314?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-09',
#    'text': 'Read the second time. Placed on Senate Legislative Calendar under General Orders. Calendar No. 1130.'},
#   'number': '7060',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Renewable Energy and Job Creation Tax Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/7060?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-08',
#    'text': 'Read twice and referred to the Committee on Energy and Natural Resources. (text of measure as introduced: CR S10815-10816)'},
#   'number': '3724',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Elko Indian Colony Expansion Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3724?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-08',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment by Unanimous Consent. (consideration: CR S10819; text as passed Senate: CR S10819; text of measure as introduced: CR S10816)'},
#   'number': '723',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution to permit the collection of clothing, toys, food, and housewares during the holiday season for charitable purposes in Senate buildings.',
#   'type': 'SRES',
#   'updateDate': '2017-12-14',
#   'updateDateIncludingText': '2017-12-14',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/723?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-08',
#    'text': 'Read twice and referred to the Committee on Foreign Relations.'},
#   'number': '3723',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': "A bill to establish a framework for coordination and cooperation on energy and environmental issues among the United States, the People's Republic of China, and India, and for other purposes.",
#   'type': 'S',
#   'updateDate': '2024-02-09',
#   'updateDateIncludingText': '2024-02-09',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3723?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-08',
#    'text': 'Read twice and referred to the Committee on Rules and Administration.'},
#   'number': '3722',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Bipartisan Electronic Voting Reform Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-09',
#   'updateDateIncludingText': '2024-02-09',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3722?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-08',
#    'text': 'Read twice and referred to the Committee on Armed Services. (text of measure as introduced: CR S10815)'},
#   'number': '3721',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to prohibit the use of funds to transfer individuals detained by the United States at Naval Station, Guantanamo Bay, Cuba, to the United States Disciplinary Barracks, Fort Leavenworth, Kansas.',
#   'type': 'S',
#   'updateDate': '2024-02-08',
#   'updateDateIncludingText': '2024-02-08',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3721?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-08',
#    'text': 'Referred to the Committee on the Judiciary. (text of measure as introduced: CR S10816)'},
#   'number': '722',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution recognizing January 2, 2009 as "National Advertising Specialty Day".',
#   'type': 'SRES',
#   'updateDate': '2019-11-15',
#   'updateDateIncludingText': '2019-11-15',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/722?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-12-08',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '3720',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to amend the Internal Revenue Code of 1986 to suspend the minimum required pension distribution rules for 2008 and 2009.',
#   'type': 'S',
#   'updateDate': '2019-11-15',
#   'updateDateIncludingText': '2019-11-15',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3720?format=json'},
#  {'congress': 110,
# ...
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '3572',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Ratepayer Recovery Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-23',
#   'updateDateIncludingText': '2024-02-23',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3572?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Referred to the Committee on Health, Education, Labor, and Pensions. (text of measure as introduced: CR S9425-9426)'},
#   'number': '103',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A concurrent resolution recognizing the 10th anniversary of the establishment of the Minority AIDS Initiative.',
#   'type': 'SCONRES',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/sconres/103?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3571',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'HIA Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3571?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '3568',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to amend the Controlled Substances Act to address the use of intrathecal pumps.',
#   'type': 'S',
#   'updateDate': '2019-11-15',
#   'updateDateIncludingText': '2019-11-15',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3568?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3570',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Public Health Coordinating Council Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3570?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Read twice and referred to the Committee on Foreign Relations.'},
#   'number': '3567',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to establish a Commission on the conflict between Russia and Georgia, and for other purposes.',
#   'type': 'S',
#   'updateDate': '2024-02-09',
#   'updateDateIncludingText': '2024-02-09',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3567?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3566',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to prohibit the Secretary of Labor from issuing, administering, or enforcing any rule, regulation, or requirement derived from the proposal submitted to the Office of Management and Budget entitled "Requirements for DOL Agencies\' Assessment of Occupational Health Risks" (RIN: 1290-AA23).',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3566?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Referred to the Committee on Banking, Housing, and Urban Affairs. (text of measure as introduced: CR S9425)'},
#   'number': '102',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A concurrent resolution expressing the sense of Congress that ensuring the availability of adequate housing is an essential component of an effective strategy for the prevention and treatment of HIV and the care of individuals with HIV.',
#   'type': 'SCONRES',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/sconres/102?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Resolution agreed to in Senate without amendment and with a preamble by Unanimous Consent. (text: CR S9437)'},
#   'number': '665',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution designating October 3, 2008, as "National Alternative Fuel Vehicle Day".',
#   'type': 'SRES',
#   'updateDate': '2019-11-15',
#   'updateDateIncludingText': '2019-11-15',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/665?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Resolution agreed to in Senate without amendment and with a preamble by Unanimous Consent. (text: CR S9436-9437)'},
#   'number': '551',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution celebrating 75 years of successful State-based alcohol regulation.',
#   'type': 'SRES',
#   'updateDate': '2019-11-15',
#   'updateDateIncludingText': '2019-11-15',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/551?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S9435-9436; text as passed Senate: CR S9436; text of measure as introduced: CR S9425)'},
#   'number': '684',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution calling for a comprehensive strategy to address the crisis in Darfur, Sudan.',
#   'type': 'SRES',
#   'updateDate': '2017-12-14',
#   'updateDateIncludingText': '2017-12-14',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/684?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S9435; text as passed Senate: CR S9435; text of measure as introduced: CR S9425)'},
#   'number': '683',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution designating the week of October 19 through October 25, 2008, as "National Childhood Lead Poisoning Prevention Week".',
#   'type': 'SRES',
#   'updateDate': '2017-12-14',
#   'updateDateIncludingText': '2017-12-14',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/683?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S9434-9435; text as passed Senate: CR S9435; text of measure as introduced: CR S9424)'},
#   'number': '682',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution recognizing Hispanic Heritage Month and celebrating the heritage and culture of Hispanic Americans and their immense contributions to the Nation.',
#   'type': 'SRES',
#   'updateDate': '2017-12-14',
#   'updateDateIncludingText': '2017-12-14',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/682?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S9434; text as passed Senate:  CR S9434; text of measure as introduced: CR S9424)'},
#   'number': '680',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution to authorize the production of records by the Permanent Subcommittee on Investigations of the Committee on Homeland Security and Governmental Affairs.',
#   'type': 'SRES',
#   'updateDate': '2017-12-14',
#   'updateDateIncludingText': '2017-12-14',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/680?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 1076.'},
#   'number': '2549',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Environmental Justice Renewal Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/2549?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 1078.'},
#   'number': '3565',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Air and Health Quality Empowerment Zone Designation Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3565?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 1077.'},
#   'number': '3564',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Restoring the Value of Every American in Environmental Decisions Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3564?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 1075.'},
#   'number': '2080',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Sewage Overflow Community Right-to-Know Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/2080?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Referred to the Committee on Rules and Administration. (text of measure as introduced: CR S9424)'},
#   'number': '681',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution to allow the part time, volunteer practice of medicine in private medical facilities.',
#   'type': 'SRES',
#   'updateDate': '2024-02-09',
#   'updateDateIncludingText': '2024-02-09',
#   'url': 'https://api.congress.gov/v3/bill/110/sres/681?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 1074.'},
#   'number': '3563',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Security Assistance Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-09',
#   'updateDateIncludingText': '2024-02-09',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3563?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 1072.'},
#   'number': '3350',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to provide that claims of the United States to certain documents relating to Franklin Delano Roosevelt shall be treated as waived and relinquished in certain circumstances.',
#   'type': 'S',
#   'updateDate': '2024-02-23',
#   'updateDateIncludingText': '2024-02-23',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3350?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'actionTime': '19:32:32',
#    'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'number': '1376',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Commemorating the 80th anniversary of the Okeechobee Hurricane of September 1928 and its associated tragic loss of life.',
#   'type': 'HRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hres/1376?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 1071.'},
#   'number': '3224',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Dam Rehabilitation and Repair Act of 2007',
#   'type': 'HR',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/3224?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 1070.'},
#   'number': '1828',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to require the Administrator of the Environmental Protection Agency to conduct a study of the feasibility of increasing the consumption in the United States of certain ethanol-blended gasoline.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/1828?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 1068.'},
#   'number': '1464',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Great Cats and Rare Canids Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/1464?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 1069.'},
#   'number': '1771',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Crane Conservation Act of 2008',
#   'type': 'HR',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/1771?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 1067.'},
#   'number': '1387',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Federal Greenhouse Gas Registry Act of 2008',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/1387?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'actionTime': '18:32:13',
#    'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'number': '1492',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Providing for agreement by the House of Representatives to the Senate amendment to the bill, H.R. 2095, with an amendment.',
#   'type': 'HRES',
#   'updateDate': '2017-12-14',
#   'updateDateIncludingText': '2022-02-08',
#   'url': 'https://api.congress.gov/v3/bill/110/hres/1492?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#   'number': '3562',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to amend the Clean Air Act to provide for the waiver of requirements relating to recertification kits for the conversion of vehicles into vehicles powered by natural gas or liquefied petroleum gas.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/110/s/3562?format=json'},
#  {'congress': 110,
#   'latestAction': {'actionDate': '2008-09-24',
#    'text': 'Placed on the Union Calendar, Calendar No. 573.'},
#   'number': '1497',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Legal Timber Protection Act',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/110/hr/1497?format=json'},
#  ...]

# %%
test[1]
# Out:
# [{'congress': 111,
#   'latestAction': {'actionDate': '2011-01-07',
#    'text': 'Became Public Law No: 111-383.'},
#   'number': '6523',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Ike Skelton National Defense Authorization Act for Fiscal Year 2011',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6523?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-05',
#    'text': 'Referred to the Subcommittee on National Parks, Forests and Public Lands.'},
#   'number': '6561',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'History Is Learned from the Living Act',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6561?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-373.'},
#   'number': '841',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Pedestrian Safety Enhancement Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/841?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-348.'},
#   'number': '81',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Shark Conservation Act of 2009',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/81?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-371.'},
#   'number': '6533',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Local Community Radio Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6533?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-370.'},
#   'number': '6510',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To direct the Administrator of General Services to convey a parcel of real property in Houston, Texas, to the Military Museum of Texas, and for other purposes.',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6510?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-369.'},
#   'number': '6412',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Access to Criminal History Records for State Sentencing Commissions Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6412?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-368.'},
#   'number': '6400',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the facility of the United States Postal Service located at 111 North 6th Street in St. Louis, Missouri, as the "Earl Wilson, Jr. Post Office".',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6400?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-367.'},
#   'number': '6392',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the facility of the United States Postal Service located at 5003 Westfields Boulevard in Centreville, Virginia, as the "Colonel George Juskalian Post Office Building".',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6392?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-349.'},
#   'number': '628',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To establish a pilot program in certain United States district courts to encourage enhancement of expertise in patent cases among district judges.',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/628?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-366.'},
#   'number': '5901',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'An act to amend the Internal Revenue Code of 1986 to authorize the tax court to appoint employees.',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5901?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-365.'},
#   'number': '5877',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the facility of the United States Postal Service located at 655 Centre Street in Jamaica Plain, Massachusetts, as the "Lance Corporal Alexander Scott Arredondo, United States Marine Corps Post Office Building".',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5877?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-364.'},
#   'number': '5809',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Diesel Emissions Reduction Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5809?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-363.'},
#   'number': '5655',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the Little River Branch facility of the United States Postal Service located at 140 NE 84th Street in Miami, Florida, as the "Jesse J. McCrary, Jr. Post Office".',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5655?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-362.'},
#   'number': '5606',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the facility of the United States Postal Service located at 47 South 7th Street in Indiana, Pennsylvania, as the "James M. \'Jimmy\' Stewart Post Office Building".',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5606?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-361.'},
#   'number': '5605',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the facility of the United States Postal Service located at 47 East Fayette Street in Uniontown, Pennsylvania, as the "George C. Marshall Post Office".',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5605?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-360.'},
#   'number': '5470',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To exclude an external power supply for certain security or life safety alarms and surveillance system components from the application of certain energy efficiency standards under the Energy Policy and Conservation Act.',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5470?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-359.'},
#   'number': '5133',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the facility of the United States Postal Service located at 331 1st Street in Carlstadt, New Jersey, as the "Staff Sergeant Frank T. Carvill and Lance Corporal Michael A. Schwarz Post Office Building".',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5133?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-358.'},
#   'number': '5116',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'America COMPETES Reauthorization Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5116?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-357.'},
#   'number': '4973',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'National Wildlife Refuge Volunteer Improvement Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/4973?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-356.'},
#   'number': '4748',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Northern Border Counternarcotics Strategy Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/4748?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-355.'},
#   'number': '4602',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the facility of the United States Postal Service located at 1332 Sharon Copley Road in Sharon Center, Ohio, as the "Emil Bolas Post Office".',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/4602?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-354.'},
#   'number': '4445',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Indian Pueblo Cultural Center Clarification Act',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/4445?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-382.'},
#   'number': '4036',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to clarify the National Credit Union Administration authority to make stabilization fund expenditures without borrowing from the Treasury.',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/4036?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-381.'},
#   'number': '3903',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to authorize leases of up to 99 years for lands held in trust for Ohkay Owingeh Pueblo.',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3903?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-380.'},
#   'number': '3874',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Reduction of Lead in Drinking Water Act',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3874?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-379.'},
#   'number': '3592',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to designate the facility of the United States Postal Service located at 100 Commerce Drive in Tyrone, Georgia, as the "First Lieutenant Robert Wilson Collins Post Office Building".',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3592?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-378.'},
#   'number': '3481',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to amend the Federal Water Pollution Control Act to clarify Federal responsibility for stormwater pollution.',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3481?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-377.'},
#   'number': '3447',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Post-9/11 Veterans Educational Assistance Improvements Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3447?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-376.'},
#   'number': '3243',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Anti-Border Corruption Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3243?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-375.'},
#   'number': '3036',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': "National Alzheimer's Project Act",
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3036?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-353.'},
#   'number': '2751',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'FDA Food Safety Modernization Act',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/2751?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-352.'},
#   'number': '2142',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'GPRA Modernization Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/2142?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-351.'},
#   'number': '1746',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Predisaster Hazard Mitigation Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/1746?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-374.'},
#   'number': '1481',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Frank Melville Supportive Housing Investment Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/1481?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-372.'},
#   'number': '118',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Section 202 Supportive Housing for the Elderly Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/118?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-04',
#    'text': 'Became Public Law No: 111-350.'},
#   'number': '1107',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To enact certain laws relating to public contracts as title 41, United States Code, "Public Contracts".',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/1107?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2011-01-02',
#    'text': 'Became Public Law No: 111-347.'},
#   'number': '847',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'James Zadroga 9/11 Health and Compensation Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/847?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-29',
#    'text': 'Became Public Law No: 111-344.'},
#   'number': '6517',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Omnibus Trade Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6517?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-29',
#    'text': 'Became Public Law No: 111-343.'},
#   'number': '6398',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To require the Federal Deposit Insurance Corporation to fully insure Interest on Lawyers Trust Accounts.',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6398?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-29',
#    'text': 'Became Public Law No: 111-346.'},
#   'number': '4058',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Helping Heroes Keep Their Homes Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/4058?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-29',
#    'text': 'Became Public Law No: 111-345.'},
#   'number': '3386',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': "Restore Online Shoppers' Confidence Act",
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3386?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-23',
#    'text': 'Referred to the Subcommittee on Air and Land Forces.'},
#   'number': '6540',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Defense Level Playing Field Act',
#   'type': 'HR',
#   'updateDate': '2024-02-08',
#   'updateDateIncludingText': '2024-02-08',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6540?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-23',
#    'text': 'Referred to the Subcommittee on Military Personnel.'},
#   'number': '6520',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': "Don't Ask, Don't Tell Repeal Act of 2010",
#   'type': 'HR',
#   'updateDate': '2023-01-11',
#   'updateDateIncludingText': '2023-01-11',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6520?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-23',
#    'text': 'Message on Senate action sent to the House.'},
#   'number': '78',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A concurrent resolution honoring the work and mission of the Delta Regional Authority on the occasion of the 10th anniversary of the Federal-State partnership created to uplift the 8-State Delta region.',
#   'type': 'SCONRES',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/sconres/78?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-23',
#    'text': 'Message on Senate action sent to the House.'},
#   'number': '71',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A concurrent resolution recognizing the United States national interest in helping to prevent and mitigate acts of genocide and other mass atrocities against civilians, and supporting and encouraging efforts to develop a whole of government approach to prevent and mitigate such acts.',
#   'type': 'SCONRES',
#   'updateDate': '2024-02-09',
#   'updateDateIncludingText': '2024-02-09',
#   'url': 'https://api.congress.gov/v3/bill/111/sconres/71?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-23',
#    'text': 'Message on Senate action sent to the House.'},
#   'number': '275',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Expressing support for designation of the week beginning on the second Sunday of September as Arts in Education Week.',
#   'type': 'HCONRES',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/hconres/275?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-330.'},
#   'number': '6516',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To make technical corrections to provisions of law enacted by the Coast Guard Authorization Act of 2010.',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6516?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-329.'},
#   'number': '6473',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Airport and Airway Extension Act of 2010, Part IV',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6473?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-328.'},
#   'number': '6278',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Kingman and Heritage Islands Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6278?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-327.'},
#   'number': '6198',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Bankruptcy Technical Corrections Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6198?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-326.'},
#   'number': '5591',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the airport traffic control tower located at Spokane International Airport in Spokane, Washington, as the "Ray Daves Airport Traffic Control Tower".',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5591?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-325.'},
#   'number': '4337',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Regulated Investment Company Modernization Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/4337?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Private Law No: 111-1.'},
#   'number': '4010',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill for the relief of Shigeru Yamada.',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/4010?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-342.'},
#   'number': '4005',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Preserving Foreign Criminal Assets for Forfeiture Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/4005?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-341.'},
#   'number': '3998',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Criminal History Background Checks Pilot Extension Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3998?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-340.'},
#   'number': '3984',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Museum and Library Services Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3984?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-339.'},
#   'number': '3860',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to require reports on the management of Arlington National Cemetery.',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3860?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-338.'},
#   'number': '3794',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'FOR VETS Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3794?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-337.'},
#   'number': '3199',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Early Hearing Detection and Intervention Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3199?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-322.'},
#   'number': '3082',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Continuing Appropriations and Surface Transportation Extensions Act, 2011',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/3082?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-331.'},
#   'number': '30',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Truth in Caller ID Act of 2009',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/30?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-321.'},
#   'number': '2965',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': "Don't Ask, Don't Tell Repeal Act of 2010",
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/2965?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-324.'},
#   'number': '2941',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': "To reauthorize and enhance Johanna's Law to increase public awareness and knowledge with respect to gynecologic cancers.",
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/2941?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-336.'},
#   'number': '2906',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to amend the Act of August 9, 1955, to modify a provision relating to leases involving certain Indian tribes.',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/2906?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Private Law No: 111-2.'},
#   'number': '1774',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill for the relief of Hotaru Nakama Ferschke.',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/1774?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-335.'},
#   'number': '1609',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Longline Catcher Processor Subsector Single Fishery Cooperative Act',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/1609?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-334.'},
#   'number': '1448',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to amend the Act of August 9, 1955, to authorize the Coquille Indian Tribe, the Confederated Tribes of Siletz Indians, the Confederated Tribes of the Coos, Lower Umpqua, and Siuslaw, the Klamath Tribes, and the Burns Paiute Tribe to obtain 99-year lease authority for trust land.',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/1448?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-333.'},
#   'number': '1405',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': "Longfellow House-Washington's Headquarters National Historic Site Designation Act",
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/1405?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-332.'},
#   'number': '1275',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'National Foundation on Fitness, Sports, and Nutrition Establishment Act',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/1275?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Became Public Law No: 111-323.'},
#   'number': '1061',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Hoh Indian Tribe Safe Homelands Act',
#   'type': 'HR',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/1061?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'By Senator Rockefeller from Committee on Commerce, Science, and Transportation filed written report. Report No. 111-388.'},
#   'number': '2870',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'International Fisheries Stewardship and Enforcement Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/2870?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'By Senator Rockefeller from Committee on Commerce, Science, and Transportation filed written report. Report No. 111-387.'},
#   'number': '1274',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': "American Communities' Right to Public Information Act",
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/1274?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Received in the Senate and Read twice and referred to the Committee on the Judiciary.'},
#   'number': '6560',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Removal Clarification Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-02-06',
#   'updateDateIncludingText': '2024-02-06',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6560?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Star Print ordered on the reported bill.'},
#   'number': '583',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Building a Stronger America Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/583?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S11058-11060; text as passed Senate: CR S11060; text of measure as introduced: CR S11038)'},
#   'number': '707',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution honoring Lula Davis.',
#   'type': 'SRES',
#   'updateDate': '2017-12-13',
#   'updateDateIncludingText': '2023-01-10',
#   'url': 'https://api.congress.gov/v3/bill/111/sres/707?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment by Unanimous Consent. (consideration: CR S11058; text as passed Senate: CR S11058; text of measure as introduced: CR S11038)'},
#   'number': '706',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution extending the authority for the Senate National Security Working Group.',
#   'type': 'SRES',
#   'updateDate': '2017-12-13',
#   'updateDateIncludingText': '2023-01-10',
#   'url': 'https://api.congress.gov/v3/bill/111/sres/706?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment by Unanimous Consent. (consideration: CR 11058; text as passed Senate: CR S11058; text of measure as introduced: CR S11038)'},
#   'number': '705',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution providing for a technical correction to S. Res. 700.',
#   'type': 'SRES',
#   'updateDate': '2017-12-13',
#   'updateDateIncludingText': '2023-01-10',
#   'url': 'https://api.congress.gov/v3/bill/111/sres/705?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Resolution agreed to in Senate without amendment and with a preamble by Unanimous Consent. (text: CR S11057-11058)'},
#   'number': '432',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill supporting the goals and ideals of the Year of the Lung 2010.',
#   'type': 'SRES',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/sres/432?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'By Senator Rockefeller from Committee on Commerce, Science, and Transportation filed written report. Report No. 111-385.'},
#   'number': '2764',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Satellite Television Extension and Localism Act of 2009',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/2764?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'By Senator Rockefeller from Committee on Commerce, Science, and Transportation filed written report. Report No. 111-386.'},
#   'number': '3304',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Twenty-First Century Communications and Video Accessibility Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-05-17',
#   'updateDateIncludingText': '2024-05-17',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3304?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'By Senator Rockefeller from Committee on Commerce, Science, and Transportation filed written report. Report No. 111-384.'},
#   'number': '773',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Cybersecurity Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/773?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Message on House action received in Senate and at desk: House amendments to Senate bill.'},
#   'number': '372',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Whistleblower Protection Enhancement Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-23',
#   'updateDateIncludingText': '2024-02-23',
#   'url': 'https://api.congress.gov/v3/bill/111/s/372?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '4059',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Choice Neighborhoods Initiative Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/4059?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '6205',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the facility of the United States Postal Service located at 1449 West Avenue in Bronx, New York, as the "Private Isaac T. Cortes Post Office".',
#   'type': 'HR',
#   'updateDate': '2024-02-23',
#   'updateDateIncludingText': '2024-02-23',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6205?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '5702',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To amend the District of Columbia Home Rule Act to reduce the waiting period for holding special elections to fill vacancies in local offices in the District of Columbia.',
#   'type': 'HR',
#   'updateDate': '2024-02-23',
#   'updateDateIncludingText': '2024-02-23',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5702?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Received in the Senate and Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '6547',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Protecting Students from Sexual and Violent Predators Act',
#   'type': 'HR',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6547?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Read twice and referred to the Committee on Rules and Administration.'},
#   'number': '5493',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To provide for the furnishing of statues by the District of Columbia and territories and possessions of the United States for display in Statuary Hall in the United States Capitol.',
#   'type': 'HR',
#   'updateDate': '2024-02-09',
#   'updateDateIncludingText': '2024-02-09',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5493?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '5446',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To designate the facility of the United States Postal Service located at 600 Florida Avenue in Cocoa, Florida, as the "Harry T. and Harriette Moore Post Office".',
#   'type': 'HR',
#   'updateDate': '2024-02-23',
#   'updateDateIncludingText': '2024-02-23',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5446?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '6494',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'To amend the National Defense Authorization Act for Fiscal Year 2010 to improve the Littoral Combat Ship program of the Navy.',
#   'type': 'HR',
#   'updateDate': '2024-02-08',
#   'updateDateIncludingText': '2024-02-08',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6494?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '5367',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'D.C. Courts and Public Defender Service Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-02-23',
#   'updateDateIncludingText': '2024-02-23',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5367?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '6397',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Marine Sergeant Michael H. Ferschke, Jr. Memorial Act',
#   'type': 'HR',
#   'updateDate': '2024-02-06',
#   'updateDateIncludingText': '2024-02-06',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/6397?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Message on Senate action sent to the House.'},
#   'number': '336',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Providing for the sine die adjournment of the second session of the One Hundred Eleventh Congress.',
#   'type': 'HCONRES',
#   'updateDate': '2023-01-11',
#   'updateDateIncludingText': '2023-01-11',
#   'url': 'https://api.congress.gov/v3/bill/111/hconres/336?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'actionTime': '17:49:02',
#    'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'number': '1784',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Appointing a committee to inform the President.',
#   'type': 'HRES',
#   'updateDate': '2023-01-11',
#   'updateDateIncludingText': '2023-01-11',
#   'url': 'https://api.congress.gov/v3/bill/111/hres/1784?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'actionTime': '17:45:35',
#    'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'number': '1783',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Making a technical correction to a cross-reference in the final regulations issued by the Office of Compliance to implement the Veterans Employment Opportunities Act of 1998 that apply to the House of Representatives and employees of the House of Representatives.',
#   'type': 'HRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/111/hres/1783?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'actionTime': '17:43:50',
#    'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'number': '1779',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Honoring the 50th anniversary of the Freedom Rides.',
#   'type': 'HRES',
#   'updateDate': '2023-01-11',
#   'updateDateIncludingText': '2023-01-11',
#   'url': 'https://api.congress.gov/v3/bill/111/hres/1779?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'actionTime': '17:41:55',
#    'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'number': '67',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A concurrent resolution celebrating 130 years of United States-Romanian diplomatic relations, congratulating the Romanian people on their achievements as a great nation, and reaffirming the deep bonds of trust and values between the United States and Romania, a trusted and most valued ally.',
#   'type': 'SCONRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/111/sconres/67?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'actionTime': '17:40:24',
#    'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'number': '1461',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Supporting Olympic Day on June 23, 2010, and congratulating Team USA and World Fit participants.',
#   'type': 'HRES',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/111/hres/1461?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'actionTime': '17:10:29',
#    'text': 'Held at the desk.'},
#   'number': '4053',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'SBIR/STTR Reauthorization Act of 2010',
#   'type': 'S',
#   'updateDate': '2023-01-11',
#   'updateDateIncludingText': '2023-01-11',
#   'url': 'https://api.congress.gov/v3/bill/111/s/4053?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Placed on the Union Calendar, Calendar No. 417.'},
#   'number': '1064',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Youth Prison Reduction through Opportunities, Mentoring, Intervention, Support, and Education Act',
#   'type': 'HR',
#   'updateDate': '2024-02-06',
#   'updateDateIncludingText': '2024-02-06',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/1064?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Placed on the Union Calendar, Calendar No. 416.'},
#   'number': '1174',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'FEMA Independence Act of 2009',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/1174?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-12-22',
#    'text': 'Placed on the Union Calendar, Calendar No. 415.'},
#   'number': '1425',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Wartime Treatment Study Act',
#   'type': 'HR',
#   'updateDate': '2024-02-05',
# ...
#    'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#   'number': '3933',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Electricity Reliability Protection Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3933?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Placed on the Union Calendar, Calendar No. 391.'},
#   'number': '5892',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Water Resources Development Act of 2010',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/5892?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '3932',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Comprehensive Immigration Reform Act of 2010',
#   'type': 'S',
#   'updateDate': '2023-01-11',
#   'updateDateIncludingText': '2023-01-11',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3932?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Armed Services. (text of measure as introduced: CR S7834)'},
#   'number': '3931',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Guardians of Freedom Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-08',
#   'updateDateIncludingText': '2024-02-08',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3931?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Referred to the Committee on Finance. (text of measure as introduced: CR S7835-7836)'},
#   'number': '664',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A resolution expressing the sense of the Senate in opposition to privatizing Social Security, raising the retirement age, or other similar cuts to benefits under title II of the Social Security Act.',
#   'type': 'SRES',
#   'updateDate': '2023-01-11',
#   'updateDateIncludingText': '2023-01-11',
#   'url': 'https://api.congress.gov/v3/bill/111/sres/664?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '3928',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Commercial Seafood Consumer Protection Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3928?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#   'number': '3930',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Hakalau Forest National Wildlife Refuge Expansion Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3930?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Energy and Natural Resources. (text of measure as introduced: CR S7833)'},
#   'number': '3927',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Sacramento-San Joaquin Delta National Heritage Area Establishment Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3927?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#   'number': '3929',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Cabin Fee Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3929?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#   'number': '3926',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Pike National Historic Trail Study Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3926?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Reported by the Committee on Agriculture. H. Rept. 111-653, Part I.'},
#   'number': '4645',
#   'originChamber': 'House',
#   'originChamberCode': 'H',
#   'title': 'Travel Restriction Reform and Export Enhancement Act',
#   'type': 'HR',
#   'updateDate': '2024-02-07',
#   'updateDateIncludingText': '2024-02-07',
#   'url': 'https://api.congress.gov/v3/bill/111/hr/4645?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Energy and Natural Resources. (text of measure as introduced: CR S7814-7832)'},
#   'number': '3925',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Implementation of National Consensus Appliance Agreements Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3925?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Foreign Relations. (text of measure as introduced: CR S7813)'},
#   'number': '3922',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Furthering International Nuclear Safety Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-09',
#   'updateDateIncludingText': '2024-02-09',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3922?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3921',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Ethical Pathway Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3921?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '3924',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Public Accountability in Health Care Implementation Act',
#   'type': 'S',
#   'updateDate': '2023-01-11',
#   'updateDateIncludingText': '2023-01-11',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3924?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '3920',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to address national security threats and vulnerabilities that could undermine economic recovery and financial markets.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3920?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#   'number': '3923',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Let the States Innovate on Sustainable Energy Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3923?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#   'number': '3919',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to remove the gray wolf from the list of threatened species or the list of endangered species published under the Endangered Species Act of 1973, and for other purposes.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3919?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Foreign Relations.'},
#   'number': '3918',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to authorize the United States participation in, and appropriations for, the United States contribution to the ninth replenishment of the resources of the Asian Development Fund and the United States subscription to the fifth general capital increase of the Asian Development Bank.',
#   'type': 'S',
#   'updateDate': '2024-02-09',
#   'updateDateIncludingText': '2024-02-09',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3918?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#   'number': '3917',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'South Utah Valley Electric Conveyance Act',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3917?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '3916',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to require the Consumer Product Safety Commission to study and report on the impact on consumers of permitting an increase in the amount of ethanol blended with gasoline for use in gasoline-powered engines used in vehicles operated in interstate commerce, on public streets and roads, or offroad, appliances such as lawn mowers and other nonvehicular devices, and marine engines, and to require the National Highway Traffic Safety Administration to study and report on any safety or reliability impact of such an increase on motor vehicle engines and fuel systems.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3916?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '3913',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Guardians of Freedom Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-08',
#   'updateDateIncludingText': '2024-02-08',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3913?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '3915',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Medicare Rural Physician Recruitment and Retention Act of 2010',
#   'type': 'S',
#   'updateDate': '2023-01-11',
#   'updateDateIncludingText': '2023-01-11',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3915?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions. (text of measure as introduced: CR S7811)'},
#   'number': '3914',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to amend title VIII of the Elementary and Secondary Education Act of 1965 to require the Secretary of Education to complete payments under such title to local educational agencies eligible for such payments within 3 fiscal years.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3914?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3907',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Debbie Blanchard Access to Health Care for Individuals With Disabilities Act of 2010',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3907?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '3912',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'HARVEST Act of 2010',
#   'type': 'S',
#   'updateDate': '2023-01-11',
#   'updateDateIncludingText': '2023-01-11',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3912?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#   'number': '3911',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to require the Secretary of the Army to operate the Buford Dam/Lake Sidney Lanier Project and the Allatoona Dam and Reservoir Project, and for other purposes.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3911?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Referred to the Committee on the Judiciary. (text of measure as introduced: CR S7840)'},
#   'number': '73',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A concurrent resolution honoring the life of Dr. Ronald W. Walters and commending his life as an example to future generations of the people of the United States.',
#   'type': 'SCONRES',
#   'updateDate': '2023-01-11',
#   'updateDateIncludingText': '2023-01-11',
#   'url': 'https://api.congress.gov/v3/bill/111/sconres/73?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '3909',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'Accountability for Defense Contractors Act',
#   'type': 'S',
#   'updateDate': '2024-02-08',
#   'updateDateIncludingText': '2024-02-08',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3909?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#   'number': '3910',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to require the Secretary of the Army to update each water control manual of the Corps of Engineers regarding the Apalachicola-Chattahoochee-Flint River system to include reallocation of storage to meet current and future municipal and industrial water supply needs, and for other purposes.',
#   'type': 'S',
#   'updateDate': '2024-02-16',
#   'updateDateIncludingText': '2024-02-16',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3910?format=json'},
#  {'congress': 111,
#   'latestAction': {'actionDate': '2010-09-29',
#    'text': "Read twice and referred to the Committee on Veterans' Affairs."},
#   'number': '3902',
#   'originChamber': 'Senate',
#   'originChamberCode': 'S',
#   'title': 'A bill to deem references to Operation Iraqi Freedom in provisions of Federal law providing benefits for service in the Armed Forces to include references to Operation New Dawn.',
#   'type': 'S',
#   'updateDate': '2024-02-09',
#   'updateDateIncludingText': '2024-02-09',
#   'url': 'https://api.congress.gov/v3/bill/111/s/3902?format=json'},
#  ...]

# %%
path = "/Users/nickgutin/Documents/GitHub/congress-project/notebooks/test_processed_bills.json"
with open(path, 'r') as file:
    data = json.load(file)

# %%
data[1]['text'].strip()
# Out:
# "[Congressional Bills 112th Congress]\n[From the U.S. Government Publishing Office]\n[H.R. 1510 Introduced in House (IH)]\n\n112th CONGRESS\n  1st Session\n                                H. R. 1510\n\nTo amend title 49, United States Code, to prohibit a pat down search of \n minor for purposes of air transportation security without the consent \n     and presence of a parent of the minor, and for other purposes.\n\n\n_______________________________________________________________________\n\n\n                    IN THE HOUSE OF REPRESENTATIVES\n\n                             April 13, 2011\n\n Mr. Chaffetz introduced the following bill; which was referred to the \n                     Committee on Homeland Security\n\n_______________________________________________________________________\n\n                                 A BILL\n\n\n \nTo amend title 49, United States Code, to prohibit a pat down search of \n minor for purposes of air transportation security without the consent \n     and presence of a parent of the minor, and for other purposes.\n\n    Be it enacted by the Senate and House of Representatives of the \nUnited States of America in Congress assembled,\n\nSECTION 1. SHORT TITLE.\n\n    This Act may be cited as the ``TSA Screening of Minors Act of \n2011''.\n\nSEC. 2. PROHIBITION ON PAT DOWN SEARCHES OF MINORS WITHOUT THE CONSENT \n              AND PRESENCE OF PARENT.\n\n    Section 44901 of title 49, United States Code, is amended--\n            (1) by striking so much as precedes the first sentence and \n        inserting the following:\n    ``(b) Screening of Passengers.--\n            ``(1) Supervision of screening.--''; and\n            (2) by adding at the end the following new paragraph:\n            ``(2) Screening of minors.--\n                    ``(A) Prohibition.--A screening of a passenger who \n                is a minor may not include a pat down search of the \n                passenger unless such search--\n                            ``(i) is conducted with the consent, and in \n                        the presence, of a parent of the minor; or\n                            ``(ii) in the case of a minor who is not \n                        accompanied by a parent, is conducted in the \n                        presence of a representative of the air carrier \n                        or foreign air carrier undertaking to provide \n                        air transportation or foreign air \n                        transportation, respectively, for which the \n                        search is conducted.\n                    ``(B) Parent defined.--In this paragraph the term \n                `parent' includes a person who is authorized to act in \n                loco parentis for purposes of providing consent with \n                respect to a pat down search under this section.''.\n                                 <all>"
